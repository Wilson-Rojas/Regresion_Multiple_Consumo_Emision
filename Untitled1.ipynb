# %%
# Multiple Linear Regression

# %%
import matplotlib.pyplot as plt 
import pandas as pd
import pylab as pl
import numpy as np
# %matplotlib inline

# %%
#Descargar todos los datos nmecesarios 
# !curl()
